# %%
import pandas as pd 
import numpy as np
import cv2

# %% [markdown]
# BO

# %%
OB_raw_data = pd.read_csv("/home/sonn/Sonn/Workspace/Projects/Anti-Obesity_GBC_NetworkPharmacology/data/raw/GO_BP.csv")

# %%
CC_raw_data = pd.read_csv("/home/sonn/Sonn/Workspace/Projects/Anti-Obesity_GBC_NetworkPharmacology/data/raw/GO_CC.csv")

# %%
MF_raw_data = pd.read_csv("/home/sonn/Sonn/Workspace/Projects/Anti-Obesity_GBC_NetworkPharmacology/data/raw/GO_MF.csv")

# %%
MF_raw_data.head(3)
# Out:
#            Category                                               Term  Count  \
# 0  GOTERM_MF_DIRECT          GO:0004089~carbonate dehydratase activity     11
# 1  GOTERM_MF_DIRECT                        GO:0008270~zinc ion binding     18
# 2  GOTERM_MF_DIRECT  GO:0001609~G protein-coupled adenosine recepto...      4
#
#            %        PValue    Genes List Total Pop Hits Pop Total  \
# 0  39.285714  8.253696e-26     CA12        CA1     CA5B       CA3
# 1  64.285714  9.851139e-17     CA12      PTPN1     MMP1      MMP2
# 2  14.285714  2.435523e-08  ADORA2A    ADORA2B   ADORA3    ADORA1
#
#   Fold Enrichment  ...           Unnamed: 20           Unnamed: 21  \
# 0             CA2  ...  7.84101154326692E-24  7.84101154326692E-24
# 1            MMP9  ...                   CA6                   CA9
# 2              28  ...                   NaN                   NaN
#
#             Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# ...

# %%
BO = []

# %%
CC = []
MF = []

# %%
for term in MF_raw_data['Term']:
    i = term.find("~")
    MF.append(term[i+1:])

# %%
for term in CC_raw_data['Term']:
    i = term.find("~")
    CC.append(term[i+1:])

# %%
for term in OB_raw_data['Term']:
    i = term.find("~")
    BO.append(term[i+1:])
# OB_raw_data

# %%
MF
# Out:
# ['carbonate dehydratase activity',
#  'zinc ion binding',
#  'G protein-coupled adenosine receptor activity',
#  'endopeptidase activity',
#  'metalloendopeptidase activity',
#  'collagen binding',
#  'serine-type endopeptidase activity',
#  'cyanamide hydratase activity',
#  'allyl-alcohol dehydrogenase activity',
#  'peptidase activity',
#  'arylesterase activity',
#  'retinal dehydrogenase activity',
#  'enzyme binding',
#  'all-trans-retinol dehydrogenase (NADP+) activity',
#  'aldose reductase (NADPH) activity',
#  'metallopeptidase activity']

# %%
MF_final = pd.DataFrame(MF)

# %%
MF_final.columns = ['MF']

# %%
MF_final['Count'] = MF_raw_data['Count']

# %%
BO_final = pd.DataFrame(BO)

# %%
CC_final = pd.DataFrame(CC)

# %%
CC_final.columns = ['CC']

# %%
BO_final.columns = ['BO']

# %%
CC_final['Count'] = CC_raw_data['Count']

# %%
BO_final['Count'] =  OB_raw_data['Count']

# %%
MF_final
# Out:
#                                                   MF  Count
# 0                     carbonate dehydratase activity     11
# 1                                   zinc ion binding     18
# 2      G protein-coupled adenosine receptor activity      4
# 3                             endopeptidase activity      5
# 4                      metalloendopeptidase activity      5
# 5                                   collagen binding      4
# 6                 serine-type endopeptidase activity      5
# 7                       cyanamide hydratase activity      2
# 8               allyl-alcohol dehydrogenase activity      2
# 9                                 peptidase activity      3
# 10                             arylesterase activity      2
# 11                    retinal dehydrogenase activity      2
# 12                                    enzyme binding      4
# 13  all-trans-retinol dehydrogenase (NADP+) activity      2
# 14                 aldose reductase (NADPH) activity      2
# ...

# %%
CC_final
# Out:
#                                  CC  Count
# 0              extracellular matrix      5
# 1               extracellular space     10
# 2              extracellular region     10
# 3           presynaptic active zone      3
# 4       basolateral plasma membrane      4
# 5                asymmetric synapse      2
# 6              presynaptic membrane      3
# 7                   plasma membrane     14
# 8            nuclear envelope lumen      2
# 9   perinuclear region of cytoplasm      5
# 10                         axolemma      2
# 11                         dendrite      4
# 12                          synapse      4
# 13                   endosome lumen      2
# 14                     cell surface      4
# 15            extracellular exosome      7
# 16                         membrane     11
# 17              apical part of cell      2
# 18           apical plasma membrane      3

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
BO_final = BO_final.sort_values(by='Count', ascending=False)

# %%
CC_final = CC_final.sort_values(by='Count', ascending=False)

# %%
MF_final = MF_final.sort_values(by='Count', ascending=False)

# %%
plt.figure(figsize=(18, 10))
sns.barplot(y='Count', x='BO', data=BO_final, palette="viridis")

plt.ylabel('Enrichment score', fontsize=12)
plt.xlabel('Biological Process (BP)', fontsize=12)
plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)


plt.figure(figsize=(18, 10))
sns.barplot(y='Count', x='CC', data=CC_final, palette="viridis")

plt.ylabel('Enrichment score', fontsize=12)
plt.xlabel('Cellular Component (CC)', fontsize=12)
plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)


plt.figure(figsize=(18, 10))
sns.barplot(y='Count', x='MF', data=MF_final, palette="viridis")

plt.ylabel('Enrichment score', fontsize=12)
plt.xlabel('Molecular Function (MF)', fontsize=12)
plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

# Hiển thị
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4561/2891989634.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='Count', x='BO', data=BO_final, palette="viridis")
# /tmp/ipykernel_4561/2891989634.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='Count', x='CC', data=CC_final, palette="viridis")
# /tmp/ipykernel_4561/2891989634.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='Count', x='MF', data=MF_final, palette="viridis")
