# %%
import pandas as pd

# %%
data = pd.read_csv("/home/sonn/Sonn/Workspace/Projects/Anti-Obesity_GBC_NetworkPharmacology/data/final/SRING.csv")

# %%
data
# Out:
#       node1    node2      w
# 0      ACHE      APP  0.937
# 1      ACHE      CA1  0.553
# 2      ACHE  ADORA2A  0.591
# 3    ADORA1   ADORA3  0.907
# 4    ADORA1  ADORA2A  0.784
# 5   ADORA2A  ADORA2B  0.937
# 6    AKR1B1      CA1  0.473
# 7    AKR1B1    PTPN1  0.522
# 8    AKR1B1  AKR1B10  0.909
# 9     ALOX5     MMP2  0.653
# 10    ALOX5     MMP9  0.478
# 11      APP     MMP2  0.592
# 12      APP     MMP9  0.644
# 13      CA1     CA12  0.488
# 14      CA1      CA2  0.833
# 15      CA1      CA3  0.701
# 16      CA1      CA4  0.449
# 17      CA1      CA7  0.702
# 18      CA1      CA6  0.544
# 19      CA1      CA9  0.515
# 20     CA12      CA7  0.405
# 21     CA12     CA14  0.569
# 22     CA12      CA4  0.640
# 23     CA12      CA9  0.739
# 24     CA14      CA4  0.662
# 25     CA14      CA9  0.615
# 26      CA2    PTPN1  0.403
# 27      CA2     MMP9  0.454
# 28      CA2      CA4  0.557
# 29      CA2      CA9  0.637
# 30      CA2      CA7  0.691
# 31      CA2      CA3  0.693
# 32      CA3      CA7  0.534
# 33      CA3      CA4  0.845
# 34      CA4     CA5A  0.412
# 35      CA4     ESR2  0.442
# 36      CA4      CA6  0.569
# 37      CA4      CA9  0.666
# 38     CA5A     CA5B  0.734
# 39     CA5A      CA6  0.400
# 40     CA5B      CA6  0.427
# 41      CA9     MMP9  0.622
# 42     ESR2     MMP2  0.400
# 43     ESR2     MMP9  0.512
# 44     MMP1     MMP2  0.930
# 45     MMP1    MMP13  0.674
# 46     MMP1    MMP12  0.625
# 47     MMP1     MMP9  0.974
# 48    MMP12     MMP2  0.492
# 49    MMP12    MMP13  0.539
# 50    MMP12     MMP9  0.697
# 51    MMP13     MMP2  0.490
# 52    MMP13     MMP9  0.589
# 53     MMP2     MMP9  0.918
